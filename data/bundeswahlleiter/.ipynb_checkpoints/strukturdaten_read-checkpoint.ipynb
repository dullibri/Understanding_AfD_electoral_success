# %% [markdown]
# ## Structural data as provided by the Federal Statistical Office of Germany (Statistisches Bundesamt)
#
# Here, we make use of the data provided by the Federal Returning Officer (Bundeswahlleiter) for the 2014 European elections https://www.bundeswahlleiter.de/en/europawahlen/2014/strukturdaten.html and the 2019 European elections https://www.bundeswahlleiter.de/en/europawahlen/2019/strukturdaten.html.

# %%
# %matplotlib notebook
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os    
from chardet import detect
import re
import scipy as stats
import camelot
from sklearn.linear_model import LinearRegression

def ele_type_per_col(df):
    """
    input: df
    output: returns list of set of datatypes per row, the first element
            is the name of the respective column
    """
    type_list = []
    for i in range(len(df.columns)):
        a = set([type(a) for a in df.iloc[:,i]])
        a = (df.columns[i],*a)
        type_list.append(a)
    return type_list

def get_encoding_type(file):
    """
    checks file type of encoding, returns string with the type
    """
    with open(file, 'rb') as f:
        rawdata = f.read()
    return detect(rawdata)['encoding']

def umlaut(string):
    """
    This function replaces replcaces umlaut-code with letter in utf-8. 
    This is useful, when detect function from chardet module does not 
    work.
    dirk.ulbricht@gmail.com, 20.9.2019
    """
    string = re.sub('Ã¼', 'ü',string)
    string = re.sub('ÃŸ', 'ß', string)
    string = re.sub('Ã¶', 'ö', string)
    string = re.sub('Ã¤', 'ä', string)
    return string


def cleaner(x):
    """
    substitutes commas with colons and returns float of it or returns nan
    """
    try:
        result = float(re.sub(',','.',x))
    except:
        result = np.nan
    return result

# %%
file='ew19_strukturdaten.csv'
# the file wouldn't read with the standard settings, therefore 
# get file encoding type and apply to read_csv

encoding = get_encoding_type(file)

struk19 = pd.read_csv(file,skiprows=range(8)
                      , encoding=encoding
                      , delimiter=';'
                      , decimal=',')
# delete "comments" ("Fußnoten")
col_sel = np.invert(['Fußnoten' in a for a in struk19.columns])
struk19 = struk19.iloc[:,col_sel]

# some of the variables have been read as obj as read_csv does 
# not handle % AND comma decimal correctly

# getting the respective columnnames as list
obj_bool = struk19.dtypes == 'object'
obj_coln = list(struk19.columns.values[obj_bool])
obj_l_ind = [a for a in range(len(struk19.columns)) if struk19.columns.values[a] in obj_coln]

# the first 2 columns are text data that do not need to be converted
# therefore [2:]
obj_coln = obj_coln[2:]

for i in obj_l_ind[2:]:
    struk19.iloc[:,i] = struk19.iloc[:,i].apply(cleaner)
struk19.iloc[:,obj_l_ind[2:]].describe()
struk19.head()
# Out:
#                  Land  Kreis                    Name  \
# 0  Schleswig-Holstein   1001        Flensburg, Stadt
# 1  Schleswig-Holstein   1002  Kiel, Landeshauptstadt
# 2  Schleswig-Holstein   1003      Lübeck, Hansestadt
# 3  Schleswig-Holstein   1004       Neumünster, Stadt
# 4  Schleswig-Holstein   1051            Dithmarschen
#
#    Gemeinden am 31.12.2017 (Anzahl)  Fläche am 31.12.2017 (km²)  \
# 0                                 1                        56.7
# 1                                 1                       118.7
# 2                                 1                       214.2
# 3                                 1                        71.7
# 4                               116                      1428.2
#
#    Bevölkerung am 31.12.2017 - Insgesamt (in 1000)  \
# 0                                             88.5
# 1                                            247.9
# 2                                            216.3
# 3                                             79.3
# 4                                            133.4
#
#    Bevölkerung am 31.12.2017 - Deutsche (in 1000)  \
# 0                                            76.8
# 1                                           220.0
# 2                                           195.4
# 3                                            70.6
# 4                                           126.0
#
#    Bevölkerung am 31.12.2017 - Ausländer (%)  \
# 0                                       13.3
# 1                                       11.3
# 2                                        9.7
# 3                                       11.0
# 4                                        5.6
#
#    Bevölkerungsdichte am 31.12.2017 (Einwohner je km²)  \
# 0                                             1560.4
# 1                                             2089.7
# 2                                             1009.9
# 3                                             1107.1
# 4                                               93.4
#
#    Zu- (+) bzw. Abnahme (-) der Bevölkerung 2017 - Geburtensaldo (je 1000 Einwohner)  \
# 0                                               -1.7
# 1                                                0.1
# 2                                               -3.6
# 3                                               -5.4
# 4                                               -5.3
#
#                         ...                         \
# 0                       ...
# 1                       ...
# 2                       ...
# 3                       ...
# 4                       ...
#
#    Sozialversicherungspflichtig Beschäftigte am 30.06.2018 - Öffentliche und private Dienstleister (%)  \
# 0                                               20.1
# 1                                               26.2
# 2                                               22.9
# 3                                               20.0
# 4                                               11.4
#
#    Sozialversicherungspflichtig Beschäftigte am 30.06.2018 - Übrige Dienstleister und "ohne Angabe" (%)  \
# 0                                               38.7
# 1                                               38.7
# 2                                               28.9
# 3                                               26.2
# 4                                               32.0
#
#    Empfänger(innen) von Leistungen nach SGB II Oktober 2018 -  insgesamt (je 1000 Einwohner)  \
# 0                                              137.9
# 1                                              140.4
# 2                                              122.5
# 3                                              123.1
# 4                                               87.8
#
#    Empfänger(innen) von Leistungen nach SGB II Oktober 2018 -  nicht erwerbsfähige Hilfebedürftige (%)  \
# 0                                               25.6
# 1                                               26.8
# 2                                               26.6
# 3                                               26.5
# 4                                               27.4
#
#    Empfänger(innen) von Leistungen nach SGB II Oktober 2018 -  Ausländer (%)  \
# 0                                               29.7
# 1                                               33.6
# 2                                               27.0
# 3                                               25.7
# 4                                               23.0
#
#    Arbeitslosenquote Januar 2019 - insgesamt  \
# 0                                        8.2
# 1                                        7.9
# 2                                        7.8
# 3                                        8.3
# 4                                        6.4
#
#    Arbeitslosenquote Januar 2019 - Männer  \
# 0                                     9.0
# 1                                     8.9
# 2                                     8.5
# 3                                     8.5
# 4                                     6.7
#
#    Arbeitslosenquote Januar 2019 - Frauen  \
# 0                                     7.2
# 1                                     6.9
# 2                                     7.0
# 3                                     7.9
# 4                                     6.0
#
#    Arbeitslosenquote Januar 2019 - 15 bis 19 Jahre  \
# 0                                              5.1
# 1                                              4.7
# 2                                              5.0
# 3                                              6.3
# 4                                              4.9
#
#    Arbeitslosenquote Januar 2019 - 55 bis 64 Jahre
# 0                                              7.7
# 1                                              8.2
# 2                                              7.6
# 3                                              7.5
# 4                                              6.3
#
# [5 rows x 51 columns]

# %%
file='ew14_strukturdaten.csv'
struk14 = pd.read_csv(file,skiprows=[0,1,2,3,5]
                      , encoding='Windows-1252'
                      , error_bad_lines=False
                      ,delimiter=';'
                      ,decimal=',')
# skip "comments"-column
col_sel = np.invert(['Bemerkungen' in a for a in struk14.columns])
struk14 = struk14.iloc[:,col_sel]

# some columns are not read as floats
obj_bool = struk14.dtypes == 'object'
obj_coln = list(struk14.columns.values[obj_bool])
obj_l_ind = [a for a in range(len(struk14.columns)) if struk14.columns.values[a] in obj_coln]
#struk14.columns.values[obj_l_ind]
struk14[obj_coln].head()

obj_coln = obj_coln[2:]

for i in obj_l_ind[2:]:
    struk14.iloc[:,i] = struk14.iloc[:,i].apply(cleaner)
struk14.describe()


#struk14.iloc[:,obj_coln]
struk14[(struk14.Kreis==3152)|(struk14.Kreis==3156)]
# Out:
#              Land  Kreis              Name  Gemeinden am 31.12.2013 (Anzahl)  \
# 23  Niedersachsen   3152         Göttingen                                29
# 27  Niedersachsen   3156  Osterode am Harz                                12
#
#     Fläche am 31.12.2012 (km²)  \
# 23                      1117.2
# 27                       636.0
#
#     Bevölkerung am 31.12.2012 - Insgesamt (in 1000)  \
# 23                                            258.1
# 27                                             75.4
#
#     Bevölkerung am 31.12.2012 - männlich (in 1000)  \
# 23                                           126.3
# 27                                            36.7
#
#     Bevölkerung am 31.12.2012 - Ausländer (in %)  \
# 23                                           7.1
# 27                                           5.2
#
#     Bevölkerungsdichte am 31.12.2012 (Einwohner je km²  \
# 23                                              231.0
# 27                                              118.6
#
#     Zu- (+) bzw. Abnahme (-) der Bevölkerung 2012 - Geburtensaldo (je 1000 Einwohner)  \
# 23                                               -2.7
# 27                                               -9.4
#
#                                                     ...                                                   \
# 23                                                  ...
# 27                                                  ...
#
#     Sozialversicherungspflichtig Beschäftigte am 30.06.2012 - Land- und Forstwirtschaft, Fischerei (%)  \
# 23                                                0.5
# 27                                                0.5
#
#     Sozialversicherungspflichtig Beschäftigte am 30.06.2012 - Produzierendes Gewerbe (%)  \
# 23                                               22.8
# 27                                               41.9
#
#     Sozialversicherungspflichtig Beschäftigte am 30.06.2012 - Handel, Gastgewerbe, Verkehr (%)  \
# 23                                               19.6
# 27                                               20.2
#
#     Sozialversicherungspflichtig Beschäftigte am 30.06.2012 - Öffentliche und private Dienstleister (%)  \
# 23                                               38.7
# 27                                               28.0
#
#     Sozialversicherungspflichtig Beschäftigte am 30.06.2012 - Übrige Dienstleister und "ohne Angabe" (%)  \
# 23                                               18.5
# 27                                                9.4
#
#     Arbeitslosenquote Ende Dezember 2013 - insgesamt  \
# 23                                               6.6
# 27                                               7.3
#
#     Arbeitslosenquote Ende Dezember 2013 - Frauen  \
# 23                                            6.2
# 27                                            7.4
#
#     Arbeitslosenquote Ende Dezember 2013 - Ausländer  \
# 23                                              14.9
# 27                                              15.7
#
#     Empfänger(innen) von Leistungen nach SGB II am 30.09.2013 -  insgesamt (je 1000 Einwohner)  \
# 23                                               70.3
# 27                                               79.8
#
#     Empfänger(innen) von Leistungen nach SGB II am 30.09.2013 -  nicht erwerbsfähige Hilfebedürftige (%)
# 23                                               27.5
# 27                                               26.3
#
# [2 rows x 42 columns]

# %%
# exporting columns for semi-automatic translation (using deepl.com) and comparison with 
# corresponding dataset 2014
pd.DataFrame(struk14.columns).to_excel('struk14_cols.xlsx')
pd.DataFrame(struk19.columns).to_excel('struk19_cols.xlsx')

# This cell reads the manually checked headings for 2019 and 2014 back in. It contains translations (transl)
# of the headings and variable names and a Comment line indicating if 2019 and 2014 values are comparable or 
# not
struk_ov = pd.read_excel('struk19_vs_struk14.xlsx')

# %%
struk_ov_19 = struk_ov[['desc_2019', 'transl_2019', 'variable_2019']]
struk_ov_19.rename({'desc_2019':'Beschreibung',
                                  'transl_2019':'Description',
                                  'variable_2019':'Variable'},inplace=True,axis=1)
struk_ov_14 = struk_ov[['desc_2014', 'transl_2014', 'variable_2014']]
struk_ov_14.rename({'desc_2014':'Beschreibung',
                                  'transl_2014':'Description',
                                  'variable_2014':'Variable'},inplace=True,axis=1)
struk_variable_descriptives = pd.concat([struk_ov_19,struk_ov_14],ignore_index=True).dropna()
struk_variable_descriptives = struk_variable_descriptives.assign(Quelle = 'Bundeswahlleiter/Statistik der Länder')
struk_variable_descriptives = struk_variable_descriptives.assign(Source = 'Federal Returning Officer/Statistik der Länder')
struk_variable_descriptives.to_csv('struk_variable_descriptives.csv', index=False)
struk_variable_descriptives.head()
# Out:
# C:\Users\dirku\Anaconda3\lib\site-packages\pandas\core\frame.py:3781: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   return super(DataFrame, self).rename(**kwargs)
#                        Beschreibung                            Description  \
# 0                              Land                                 region
# 1                             Kreis                                 county
# 2                              Name                                   name
# 3  Gemeinden am 31.12.2017 (Anzahl)  Municipalities on 31.12.2017 (number)
# 4        Fläche am 31.12.2017 (km²)               Area on 31.12.2017 (km²)
#
#               Variable                                 Quelle  \
# 0          region_2019  Bundeswahlleiter/Statistik der Länder
# 1          county_2019  Bundeswahlleiter/Statistik der Länder
# 2            name_2019  Bundeswahlleiter/Statistik der Länder
# 3  municipalities_2017  Bundeswahlleiter/Statistik der Länder
# 4            area_2017  Bundeswahlleiter/Statistik der Länder
#
#                                            Source
# 0  Federal Returning Officer/Statistik der Länder
# 1  Federal Returning Officer/Statistik der Länder
# 2  Federal Returning Officer/Statistik der Länder
# 3  Federal Returning Officer/Statistik der Länder
# 4  Federal Returning Officer/Statistik der Länder

# %%
# Renaming the variables for ease of typing
rn_19 = dict()
for i in range(len(struk_ov)):
    old_name = struk_ov.desc_2019.iloc[i]
    new_name = struk_ov.variable_2019.iloc[i]
    #print(old_name)
    if isinstance(old_name,str) and (old_name in struk19.columns):
        rn_19.update({old_name: new_name})
type(struk19)
[a in struk19.columns for a in struk_ov.desc_2019]
struk19 = struk19.rename(columns=rn_19)

rn_14 = dict()
for i in range(len(struk_ov)):
    old_name = struk_ov.desc_2014.iloc[i]
    new_name = struk_ov.variable_2014.iloc[i]
    #print(old_name)
    if isinstance(old_name,str) and (old_name in struk14.columns):
        rn_14.update({old_name: new_name})

struk14 = struk14.rename(columns=rn_14)

# %%
# to regions, Goettingen with regional key 3152 and Osterrode with regional key 3156 merged 2016-11-1 with 
# Goettingen becoming a unified region named Goettingen with regional key 3159. Variables are adjusted manually 
# and read back in.

#struk14[(struk14.county_2014==3152)|(struk14.county_2014==3156)].to_excel('Goettingen_correction.xlsx')

goettingen =  [a[0] for a in pd.read_excel('Goettingen_correction.xlsx',sheet_name = 'Tabelle1').iloc[:,[2]].values]
goettingen.pop(1)
struk14 = struk14.set_index('county_2014')
struk14.loc['3159']=goettingen
struk14 = struk14.drop(index=[3156,3152])
struk14.reset_index(inplace=True)

# %%
# creating new features containing changes
comparable = struk_ov.iloc[6:,]
comparable = comparable[comparable['Comment']=='comparable']
for i in range(len(comparable)):
    #print(i)
    var19 = comparable.variable_2019.iloc[i]
    var14 = comparable.variable_2014.iloc[i]
    var_ch = var19+'_'+var14[-4:]
    #if var14
    struk19[var_ch] = (struk19[var19] - struk14[var14])/struk14[var14]*100

struk19.rename(columns={'county_2019':'Nr'}, inplace=True)
struk19 = struk19.set_index('Nr')

# dropping some meta-data columns
struk19 = struk19.iloc[:,3:]

# same with struk14
struk14.rename(columns={'county_2014':'Nr'}, inplace=True)
struk14.set_index('Nr',inplace=True)
struk14.index = struk14.index.astype('int64')
struk14 = struk14.iloc[:,3:]

struk19 = struk19.merge(struk14,left_index=True,right_index=True,how='left')

struk19.to_csv('strukturdaten.csv',index=True,sep=';')
struk19.head()
#struk19.columns
struk19.dtypes
# Out:
# area_2017                                                                                            float64
# population_2017                                                                                      float64
# germans_2017                                                                                         float64
# foreigners_2017                                                                                      float64
# population_density_2017                                                                              float64
# birth_balance_2017                                                                                   float64
# net_migration_2017                                                                                   float64
# age_to_18_2017                                                                                       float64
# age_18_24_2017                                                                                       float64
# age_25_34_2017                                                                                       float64
# age_35_59_2017                                                                                       float64
# ag4_60_74_2017                                                                                       float64
# age_75_more_2017                                                                                     float64
# disposable_inc_2016                                                                                    int64
# gdp_2016                                                                                               int64
# protection_total_2017                                                                                float64
# protection_open_2017                                                                                 float64
# protection_accepted_2017                                                                             float64
# protection_rejected_2017                                                                             float64
# dwellings_new_2017                                                                                   float64
# dwellings_2017                                                                                       float64
# space_per_app_2017                                                                                   float64
# space_per_inh_2017                                                                                   float64
# vehicles_2018                                                                                        float64
# graduates_voc_2017                                                                                   float64
# Absolventen/Abgänger allgemeinbildender Schulen 2017 - insgesamt ohne Externe (je 1000 Einwohner)    float64
# graduates_without_secondary_2017                                                                     float64
# graduates_lower_secondary_2017                                                                       float64
# graduates_secondary_2017                                                                             float64
# graduates_higher_2017                                                                                float64
#                                                                                                       ...
# age_18_24_2012                                                                                       float64
# age_25_34_2012                                                                                       float64
# age_35_59_2012                                                                                       float64
# ag4_60_74_2012                                                                                       float64
# age_75_more_2012                                                                                     float64
# graduates_sec_2012                                                                                   float64
# graduates_without_secondary_2012                                                                     float64
# graduates_lower_secondary_2012                                                                       float64
# graduates_secondary_2012                                                                             float64
# graduates_uni_2012                                                                                   float64
# vehicles_2013                                                                                        float64
# dwellings_new_2012                                                                                   float64
# dwellings_2012                                                                                       float64
# mining_manuf_2012                                                                                    float64
# trade_tax_per_inh_2012                                                                               float64
# business_reg_2012                                                                                    float64
# business_delist_2012                                                                                 float64
# insolvencies_2012                                                                                    float64
# insolvencies_per_1000_2012                                                                           float64
# empl_soc_sec_total_2012                                                                              float64
# empl_agr_2012                                                                                        float64
# empl_manuf_2012                                                                                      float64
# empl_com_hotel_2012                                                                                  float64
# empl_service_2012                                                                                    float64
# empl_oth_service_2012                                                                                float64
# unempl_total_2013                                                                                    float64
# unempl_male_2013                                                                                     float64
# unempl_female_2013                                                                                   float64
# hartz_total_2013                                                                                     float64
# hartz_no_empl_2013                                                                                   float64
# Length: 114, dtype: object

# %%
# check if merged region Goettingen is correctly entered
struk19.loc[3159]
# Out:
# area_2017                                                                                             1755.600000
# population_2017                                                                                        328.000000
# germans_2017                                                                                           301.400000
# foreigners_2017                                                                                          8.100000
# population_density_2017                                                                                186.900000
# birth_balance_2017                                                                                      -3.600000
# net_migration_2017                                                                                       7.300000
# age_to_18_2017                                                                                          15.200000
# age_18_24_2017                                                                                           9.400000
# age_25_34_2017                                                                                          13.200000
# age_35_59_2017                                                                                          33.300000
# ag4_60_74_2017                                                                                          17.100000
# age_75_more_2017                                                                                        11.800000
# disposable_inc_2016                                                                                  20264.000000
# gdp_2016                                                                                             33320.000000
# protection_total_2017                                                                                   19.200000
# protection_open_2017                                                                                    27.100000
# protection_accepted_2017                                                                                58.500000
# protection_rejected_2017                                                                                14.400000
# dwellings_new_2017                                                                                       2.100000
# dwellings_2017                                                                                         536.300000
# space_per_app_2017                                                                                      92.700000
# space_per_inh_2017                                                                                      49.700000
# vehicles_2018                                                                                          665.800000
# graduates_voc_2017                                                                                       5.400000
# Absolventen/Abgänger allgemeinbildender Schulen 2017 - insgesamt ohne Externe (je 1000 Einwohner)        9.000000
# graduates_without_secondary_2017                                                                         4.200000
# graduates_lower_secondary_2017                                                                          13.200000
# graduates_secondary_2017                                                                                38.800000
# graduates_higher_2017                                                                                   43.700000
#                                                                                                          ...
# age_18_24_2012                                                                                           8.999130
# age_25_34_2012                                                                                          12.746957
# age_35_59_2012                                                                                          36.019130
# ag4_60_74_2012                                                                                          16.985217
# age_75_more_2012                                                                                        10.417391
# graduates_sec_2012                                                                                      10.193913
# graduates_without_secondary_2012                                                                         4.439130
# graduates_lower_secondary_2012                                                                          15.511304
# graduates_secondary_2012                                                                                39.212174
# graduates_uni_2012                                                                                      40.814783
# vehicles_2013                                                                                          615.573043
# dwellings_new_2012                                                                                       0.832174
# dwellings_2012                                                                                         533.813913
# mining_manuf_2012                                                                                        0.590435
# trade_tax_per_inh_2012                                                                                 389.304348
# business_reg_2012                                                                                        6.732174
# business_delist_2012                                                                                     6.671304
# insolvencies_2012                                                                                        1.958261
# insolvencies_per_1000_2012                                                                               1.428696
# empl_soc_sec_total_2012                                                                                353.300000
# empl_agr_2012                                                                                            0.500000
# empl_manuf_2012                                                                                         26.683135
# empl_com_hotel_2012                                                                                     19.721983
# empl_service_2012                                                                                       36.524631
# empl_oth_service_2012                                                                                   16.649920
# unempl_total_2013                                                                                             NaN
# unempl_male_2013                                                                                              NaN
# unempl_female_2013                                                                                            NaN
# hartz_total_2013                                                                                        72.447826
# hartz_no_empl_2013                                                                                      26.862025
# Name: 3159, Length: 114, dtype: float64
